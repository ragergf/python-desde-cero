# %% [markdown]
# # Reel 13 — Diccionarios en Python (Nivel Fácil)
#
# Mini notebook alineado al reel: hook, presentación, escenas de Handler, explicación con código, giro mental y CTA.

# %% [markdown]
# ## Celda 1 — HOOK
#
# **Guion:**
#
# Si estás usando listas para todo… mira esto.
#
# Aquí tengo datos… pero tengo que recordar qué significa cada posición.
#
# ¿0 era nombre? ¿1 era edad?
#
# Esto… no escala.

# %%
# ❌ Ejemplo con lista (limitado)
datos = ["Ana", 25, "CDMX"]

print(datos[0])  # ¿Qué era esto?

# %% [markdown]
# ## Celda 2 — PRESENTACIÓN
#
# **Guion:**
#
# Ahora mira esto…
#
# Esto es un diccionario.
#
# En lugar de posiciones… usas palabras.
#
# Y eso cambia TODO.

# %%
# ✅ Diccionario básico
persona = {
    "nombre": "Ana",
    "edad": 25,
    "ciudad": "CDMX"
}

print(persona)

# %% [markdown]
# ## Celda 3 — HANDLER ESCENA 1
#
# **Narrador:**
#
# Un diccionario no guarda datos… guarda relaciones.
#
# **Prompt de Grok:**
#
# ```text
# Semi-realistic 3D stylized futuristic robot named Handler,
# full monochromatic electric blue metallic armor with darker navy panel variations,
# cyan glowing circuitry lines across the body,
# metallic satin finish,
# Unreal Engine cinematic render style,
# cyberpunk blue-purple ambient glow,
# vertical 9:16,
# Handler floating in a digital environment manipulating holographic key-value pairs connected by glowing lines,
# abstract data nodes linking keys to values,
# dramatic lighting, depth of field, rim light, volumetric light
# ```

# %%
# Handler Scene 1
# Un diccionario no guarda datos… guarda relaciones.

# %% [markdown]
# ## Celda 4 — EXPLICACIÓN + CÓDIGO
#
# **Guion:**
#
# Esto es donde Python se vuelve poderoso.
#
# Aquí no buscas por número… buscas por significado.
#
# “nombre” → Ana
#
# “edad” → 25
#
# Y lo mejor… puedes agregar, cambiar y recorrer todo fácilmente.
#
# Esto ya se parece al mundo real.

# %%
persona = {
    "nombre": "Ana",
    "edad": 25,
    "ciudad": "CDMX"
}

# Acceder
print(persona["nombre"])

# Agregar
persona["profesion"] = "Ingeniera"

# Modificar
persona["edad"] = 26

# Recorrer
for clave, valor in persona.items():
    print(clave, ":", valor)

# %% [markdown]
# ## Celda 5 — HANDLER ESCENA 2
#
# **Narrador:**
#
# Así funcionan APIs… bases de datos… y sistemas reales.
#
# **Prompt de Grok:**
#
# ```text
# Semi-realistic 3D stylized futuristic robot named Handler,
# full monochromatic electric blue metallic armor with darker navy panel variations,
# cyan glowing circuitry lines across the body,
# metallic satin finish,
# Unreal Engine cinematic render style,
# cyberpunk blue-purple ambient glow,
# vertical 9:16,
# Handler inside a futuristic data system with floating API responses and database structures represented as key-value maps,
# digital connections flowing between systems,
# dramatic lighting, depth of field, rim light, volumetric light
# ```

# %%
# Handler Scene 2
# Así funcionan APIs, bases de datos y sistemas reales.

# %% [markdown]
# ## Celda 6 — GIRO MENTAL
#
# **Guion:**
#
# Esto ya no es teoría…
#
# Esto es exactamente lo que regresa una API.
#
# Todo en tecnología moderna… son diccionarios dentro de diccionarios.

# %%
# Simulación tipo API (diccionario realista)
response = {
    "status": "success",
    "data": {
        "user": "Ana",
        "role": "admin"
    }
}

print(response["data"]["user"])

# %% [markdown]
# ## Celda 7 — HANDLER FINAL
#
# **Narrador:**
#
# La base está lista… ahora subimos de nivel.
#
# **Prompt de Grok:**
#
# ```text
# Semi-realistic 3D stylized futuristic robot named Handler,
# full monochromatic electric blue metallic armor with darker navy panel variations,
# cyan glowing circuitry lines across the body,
# metallic satin finish,
# Unreal Engine cinematic render style,
# cyberpunk blue-purple ambient glow,
# vertical 9:16,
# Handler standing powerfully with a glowing dictionary structure expanding into a complex system behind him,
# symbolizing progression to advanced level,
# dramatic lighting, depth of field, rim light, volumetric light
# ```

# %%
# Handler Scene Final
# La base está lista… ahora subimos de nivel.

# %% [markdown]
# ## Celda 8 — CTA
#
# **Guion:**
#
# Guarda este notebook…
#
# porque en el siguiente nivel…
#
# esto se conecta con APIs reales.

# %%
# Siguiente nivel...
print("Nivel medio: diccionarios + APIs 🔥")
